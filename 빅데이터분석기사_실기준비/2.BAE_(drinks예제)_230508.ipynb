# %% [markdown]
# ####  1. DATA 불러오기

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows',200)
pd.set_option('display.max_columns',10)

# %%
df = pd.read_csv('./data/drinks.csv')
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
# 컬럼명 변경하기
df.columns = ['국가','맥주','증류주','와인','알코올','대륙']
df.head(3)
# Out:
#             국가  맥주  증류주  와인  알코올  대륙
# 0  Afghanistan   0    0   0  0.0  AS
# 1      Albania  89  132  54  4.9  EU
# 2      Algeria  25    0  14  0.7  AF

# %%
df.info()
# 대륙 컬럼의 갯수 다른 컬럼 대비해서 적음 null 값 있음
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가      193 non-null    object
#  1   맥주      193 non-null    int64
#  2   증류주     193 non-null    int64
#  3   와인      193 non-null    int64
#  4   알코올     193 non-null    float64
#  5   대륙      170 non-null    object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 9.2+ KB

# %% [markdown]
# #### 2. 결측치 확인
# - 결측치
#
# - 값이 없음을 나타냄
# - NaN, NaT, None 등으로 표기되며, NA Value, Missing Value 라고 함
# - 결측치 확인
#
# - DataFrame.isna() : 결측치에 대해 True, 아니면 False
# - DataFrame.isnull() : DataFrame.isna()와 동일함
# - DataFrame.notna() : 결측치가 아닌 것에 대해 True, 결측치면 False
# - DataFrame.notnull() : DataFrame.isnull()과 동일함
# - Series에도 결측치 확인을 위한 isna() ~ notnull()의 메서드 있음
# - DataFrame.isna().sum() : 결측치에 대해 컬럼별 개수

# %% [markdown]
# - 데이터 종류 확인
#
# - 주로 범주형 데이터에 사용함
# - 성별, 지역, 부서 등의 몇 개의 그룹으로 표현되는 데이터
# - 숫자 또는 문자열로 표현 될 수 있음
# - Series.unique() : 결측치를 포함하며, 중복을 제외한 데이터의 종류를 ndarray로 반환
# - Series.value_counts() : 결측치를 포함하지 않으며, 데이터 종류별 개수를 Series로 반환

# %%
# 대륙의 종류 파악하기
# df['대륙'].unique()
pd.Series((df['대륙']).unique())
# Out:
# 0     AS
# 1     EU
# 2     AF
# 3    NaN
# 4     SA
# 5     OC
# dtype: object

# %%
# 대륙별 개수
# 결측치(nan) 제외하고 나옴
df['대륙'].value_counts()
# Out:
# AF    53
# EU    45
# AS    44
# OC    16
# SA    12
# Name: 대륙, dtype: int64

# %%
df.isna()
# Out:
#         국가     맥주    증류주     와인    알코올     대륙
# 0    False  False  False  False  False  False
# 1    False  False  False  False  False  False
# 2    False  False  False  False  False  False
# 3    False  False  False  False  False  False
# 4    False  False  False  False  False  False
# 5    False  False  False  False  False   True
# 6    False  False  False  False  False  False
# 7    False  False  False  False  False  False
# 8    False  False  False  False  False  False
# 9    False  False  False  False  False  False
# 10   False  False  False  False  False  False
# 11   False  False  False  False  False   True
# 12   False  False  False  False  False  False
# 13   False  False  False  False  False  False
# 14   False  False  False  False  False   True
# 15   False  False  False  False  False  False
# 16   False  False  False  False  False  False
# 17   False  False  False  False  False   True
# 18   False  False  False  False  False  False
# 19   False  False  False  False  False  False
# 20   False  False  False  False  False  False
# 21   False  False  False  False  False  False
# 22   False  False  False  False  False  False
# 23   False  False  False  False  False  False
# 24   False  False  False  False  False  False
# 25   False  False  False  False  False  False
# 26   False  False  False  False  False  False
# 27   False  False  False  False  False  False
# 28   False  False  False  False  False  False
# 29   False  False  False  False  False  False
# 30   False  False  False  False  False  False
# 31   False  False  False  False  False  False
# 32   False  False  False  False  False   True
# 33   False  False  False  False  False  False
# 34   False  False  False  False  False  False
# 35   False  False  False  False  False  False
# 144                     St. Lucia  171  315   71  10.1  NaN
# 145  St. Vincent & the Grenadines  120  221   11   6.3  NaN
# 174             Trinidad & Tobago  197  156    7   6.4  NaN
# 184                           USA  249  158   84   8.7  NaN

# %%
# NA(North America)를 결측치로 인식하는 이슈 발생

# %% [markdown]
# #### 3. 결측치 해결 방법
# - pd.read_csv(파일이름, na_filter=False) : NA를 NaN(결측치)로 읽는 동작을 멈추게 합니다.
# - 옵션 확인 : https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.htm
# - DataFrame.fillna(값) : 결측값을 특정 값으로 채우기 합니다.
# - Series.fillna(값) : 결측값을 특정 값으로 채우기 합니다.
# - 연속형 데이터 : 0으로 채우기, 평균값으로 채우기, 범주별 평균값 채우기 등
# - 범주형 데이터 : 다른 범주로 만들어 채우기
# - DataFrame.loc[Series.isna(), 컬럼명] = 값

# %%
temp = pd.read_csv('./data/drinks.csv',na_filter = False)
temp['continent'].unique() # NA가 대륙으로 인식
# Out:
# array(['AS', 'EU', 'AF', 'NA', 'SA', 'OC'], dtype=object)

# %%
temp.isna().sum()
# Out:
# country                         0
# beer_servings                   0
# spirit_servings                 0
# wine_servings                   0
# total_litres_of_pure_alcohol    0
# continent                       0
# dtype: int64

# %%
df['대륙'] = df['대륙'].fillna('NA')

# %%
df.isna().sum()
# Out:
# 국가     0
# 맥주     0
# 증류주    0
# 와인     0
# 알코올    0
# 대륙     0
# dtype: int64

# %%
df['대륙'].unique()
# Out:
# array(['AS', 'EU', 'AF', 'NA', 'SA', 'OC'], dtype=object)

# %%
df.loc[df['대륙'].isna(),'대륙'] = 'NA'
df = df.fillna('NA')

# %% [markdown]
# #### 4. 통계구하기

# %% [markdown]
# - DataFrame.describe() : 숫자형 데이터타입을 갖는 컬럼에 대해 count, mean, std, min, max, Q1, Q2, Q3 등의 통계값 구하기
# - DataFrame.count() : 개수
# - DataFrame.sum() : 합계
# - DataFrame.mean() : 평균
# - DataFrame.std() : 표준편차
# - DataFrame.var() : 분산
# - DataFrame.quantile() : 분위수
# - DataFrame.함수(axis=1)을 사용하여 행별 통계값을 구할 수 있음
# - axis=0 : 기본값이며, 행을 이동하며, 행과 행의 연산을 수행함
# - axis=1 : 컬럼을 이동하며 컬럼과 컬럼의 연산을 수행함

# %%
# 기본통계
df.describe()
# Out:
#                맥주         증류주          와인         알코올
# count  193.000000  193.000000  193.000000  193.000000
# mean   106.160622   80.994819   49.450777    4.717098
# std    101.143103   88.284312   79.697598    3.773298
# min      0.000000    0.000000    0.000000    0.000000
# 25%     20.000000    4.000000    1.000000    1.300000
# 50%     76.000000   56.000000    8.000000    4.200000
# 75%    188.000000  128.000000   59.000000    7.200000
# max    376.000000  438.000000  370.000000   14.400000

# %%
temp = df[['국가','대륙']] #범주형데이터
temp.describe()
# Out:
#                  국가   대륙
# count           193  193
# unique          193    6
# top     Afghanistan   AF
# freq              1   53

# %%
df2 = df[['맥주','증류주','와인','알코올']]
df2.head()
# Out:
#     맥주  증류주   와인   알코올
# 0    0    0    0   0.0
# 1   89  132   54   4.9
# 2   25    0   14   0.7
# 3  245  138  312  12.4
# 4  217   57   45   5.9

# %%
# 평균과 중앙값 보고 데이터가 몰려있는지 고르게 분포 되어있는지 확인

# %%
#평균
df2.mean()
# Out:
# 맥주     106.160622
# 증류주     80.994819
# 와인      49.450777
# 알코올      4.717098
# dtype: float64

# %%
#중앙값
df2.median()
# Out:
# 맥주     76.0
# 증류주    56.0
# 와인      8.0
# 알코올     4.2
# dtype: float64

# %%
 df2.min()
# Out:
# 맥주     0.0
# 증류주    0.0
# 와인     0.0
# 알코올    0.0
# dtype: float64

# %%
temp = df2.quantile([0.25,0.5,0.75])
temp.index = ['Q1','Q2','Q3']
temp
# Out:
#        맥주    증류주    와인  알코올
# Q1   20.0    4.0   1.0  1.3
# Q2   76.0   56.0   8.0  4.2
# Q3  188.0  128.0  59.0  7.2

# %%
#표준편차
df2.std()
# Out:
# 맥주     101.143103
# 증류주     88.284312
# 와인      79.697598
# 알코올      3.773298
# dtype: float64

# %%
#분산
df2.var()
# Out:
# 맥주     10229.927191
# 증류주     7794.119765
# 와인      6351.707200
# 알코올       14.237779
# dtype: float64

# %%
df.min() # 텍스트 데이터는 A,B,C 순
# Out:
# 국가     Afghanistan
# 맥주               0
# 증류주              0
# 와인               0
# 알코올            0.0
# 대륙              AF
# dtype: object

# %%
df.max()
# Out:
# 국가     Zimbabwe
# 맥주          376
# 증류주         438
# 와인          370
# 알코올        14.4
# 대륙           SA
# dtype: object

# %% [markdown]
# - 각 컬럼 별 함수 적용
#
# - DataFrame.apply(함수) : Series로 결과가 반환됨
# - DataFrame.apply([함수1, 함수2, ...]) : DataFrame으로 결과가 반환됨
# - 사용자 정의 함수, 외부 함수, 내장 함수 등 다양한 함수를 사용할 수 있음
# - Series의 통계 함수들은 문자열 형태로 사용할 수 있음 : 'min', 'max', 'count', 'std', 'var', 'mean', 'median'

# %%
#apply 여러개 쓰고 싶을 때 유용
df2.apply(['min','max','mean'])
# Out:
#               맥주         증류주          와인        알코올
# min     0.000000    0.000000    0.000000   0.000000
# max   376.000000  438.000000  370.000000  14.400000
# mean  106.160622   80.994819   49.450777   4.717098

# %%
# 와인 소비량이 맥주+증류주 소비량보다 큰 나라를 대륙 기준으로 기준
# 4개 대륙 확인
df[df['와인'] > (df['맥주']+df['증류주'])]
# Out:
#                       국가   맥주  증류주   와인   알코올  대륙
# 6              Argentina  193   25  221   8.3  SA
# 55     Equatorial Guinea   92    0  233   5.8  AF
# 61                France  127  151  370  11.8  EU
# 83                 Italy   85   42  237   6.5  EU
# 92                  Laos   62    0  123   6.2  AS
# 136             Portugal  194   67  339  11.0  EU
# 148  Sao Tome & Principe   56   38  140   4.2  AF
# 171          Timor-Leste    1    1    4   0.1  AS
# 185              Uruguay  115   35  220   6.6  SA

# %%
# 맥주 소비량이 230 초과이면서, 와인 소비량이 230 초과인 나라
df[(df['맥주'] > 230)&(df['와인'] > 230)]
# Out:
#              국가   맥주  증류주   와인   알코올  대륙
# 3       Andorra  245  138  312  12.4  EU
# 99   Luxembourg  236  133  271  11.4  EU
# 156    Slovenia  270   51  276  10.6  EU

# %%
# 대륙이 AS인 국가들의 정보 검색
df[df['대륙'] == 'AS']
# Out:
#                        국가   맥주  증류주   와인   알코올  대륙
# 0             Afghanistan    0    0    0   0.0  AS
# 12                Bahrain   42   63    7   2.0  AS
# 13             Bangladesh    0    0    0   0.0  AS
# 19                 Bhutan   23    0    0   0.4  AS
# 24                 Brunei   31    2    1   0.6  AS
# 30               Cambodia   57   65    1   2.2  AS
# 36                  China   79  192    8   5.0  AS
# 46            North Korea    0    0    0   0.0  AS
# 77                  India    9  114    0   2.2  AS
# 78              Indonesia    5    1    0   0.1  AS
# 79                   Iran    0    0    0   0.0  AS
# 80                   Iraq    9    3    0   0.2  AS
# 82                 Israel   63   69    9   2.5  AS
# 85                  Japan   77  202   16   7.0  AS
# 86                 Jordan    6   21    1   0.5  AS
# 87             Kazakhstan  124  246   12   6.8  AS
# 90                 Kuwait    0    0    0   0.0  AS
# 91             Kyrgyzstan   31   97    6   2.4  AS
# 92                   Laos   62    0  123   6.2  AS
# 94                Lebanon   20   55   31   1.9  AS
# 102              Malaysia   13    4    0   0.3  AS
# 103              Maldives    0    0    0   0.0  AS
# 112              Mongolia   77  189    8   4.9  AS
# 116               Myanmar    5    1    0   0.1  AS
# 119                 Nepal    5    6    0   0.2  AS
# 127                  Oman   22   16    1   0.7  AS
# 128              Pakistan    0    0    0   0.0  AS
# 134           Philippines   71  186    1   4.6  AS
# 137                 Qatar    1   42    7   0.9  AS
# 138           South Korea  140   16    9   9.8  AS
# 141    Russian Federation  247  326   73  11.5  AS
# 149          Saudi Arabia    0    5    0   0.1  AS
# 154             Singapore   60   12   11   1.5  AS
# 161             Sri Lanka   16  104    0   2.2  AS
# 167                 Syria    5   35   16   1.0  AS
# 168            Tajikistan    2   15    0   0.3  AS
# 169              Thailand   99  258    1   6.4  AS
# 171           Timor-Leste    1    1    4   0.1  AS
# 176                Turkey   51   22    7   1.4  AS
# 177          Turkmenistan   19   71   32   2.2  AS
# 181  United Arab Emirates   16  135    5   2.8  AS
# 186            Uzbekistan   25  101    8   2.4  AS
# 189               Vietnam  111    2    1   2.0  AS
# 190                 Yemen    6    0    0   0.1  AS

# %% [markdown]
# DataFrame에 새로운 컬럼 추가
#
# - DataFrame[컬럼명] = 데이터목록
# - 컬럼명은 기존 DataFrame에 존재하지 않는 이름이어야 함
# - 데이터목록은 DataFrame의 다른 컬럼들과 같은 개수이어야 하며 list, Series 등의 형태일 수 있음
# - DataFrame의 컬럼 제거
#
# - del DataFrame[컬럼명]
# - DataFrame.drop(컬럼명, axis=1), DataFrame.drop([컬럼명1, 컬럼명2, ...], axis=1)
# - DataFrame.drop(columns=[컬럼명...])
#
# DataFrame의 행 제거
#
# - axis=0 이 기본값이므로 생략하여도 됨
# - DataFrame.drop(행이름), DataFrame.drop([행이름1, 행이름2, ...])
# - DataFrame.drop(rows=[행이름1, 행이름2 ...])

# %%
# 국가 별 주류 소비량 합계를 구해서 '주류소비량' 칼럼 추가
df['주류소비량'] = df['맥주']+df['증류주']+df['와인']
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량
# 0  Afghanistan    0    0    0   0.0  AS      0
# 1      Albania   89  132   54   4.9  EU    275
# 2      Algeria   25    0   14   0.7  AF     39
# 3      Andorra  245  138  312  12.4  EU    695
# 4       Angola  217   57   45   5.9  AF    319

# %%
# 주류소비량2 = 맥주,증류주, 와인에 대해 DataFrame.sum(axis=1) 함수사용
df['주류소비량2'] = df[['맥주','증류주','와인']].sum(axis=1) #axis 행별로 합
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량  주류소비량2
# 0  Afghanistan    0    0    0   0.0  AS      0       0
# 1      Albania   89  132   54   4.9  EU    275     275
# 2      Algeria   25    0   14   0.7  AF     39      39
# 3      Andorra  245  138  312  12.4  EU    695     695
# 4       Angola  217   57   45   5.9  AF    319     319

# %%
# 알코올비율 = 알코올/주류소비량
df['알코올비율'] = df['알코올']/df['주류소비량']
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량  주류소비량2     알코올비율
# 0  Afghanistan    0    0    0   0.0  AS      0       0       NaN
# 1      Albania   89  132   54   4.9  EU    275     275  0.017818
# 2      Algeria   25    0   14   0.7  AF     39      39  0.017949
# 3      Andorra  245  138  312  12.4  EU    695     695  0.017842
# 4       Angola  217   57   45   5.9  AF    319     319  0.018495

# %%
# 알코올비율이 높은 TOP5 국가의 국가,주류소비량,알코올비율 정보 구하기
df[['국가','주류소비량','알코올비율']].sort_values('알코올비율',ascending = False).head(5)
# Out:
#                국가  주류소비량     알코올비율
# 63         Gambia      9  0.266667
# 153  Sierra Leone     30  0.223333
# 124       Nigeria     49  0.185714
# 179        Uganda     54  0.153704
# 142        Rwanda     45  0.151111

# %%
# 주류소비량2 컬럼 제거, inplace 쓰기 or 'df='' 데이터프레임 재정의
df.drop('주류소비량2',axis=1,inplace=True)
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량     알코올비율
# 0  Afghanistan    0    0    0   0.0  AS      0       NaN
# 1      Albania   89  132   54   4.9  EU    275  0.017818
# 2      Algeria   25    0   14   0.7  AF     39  0.017949
# 3      Andorra  245  138  312  12.4  EU    695  0.017842
# 4       Angola  217   57   45   5.9  AF    319  0.018495

# %%
# 알코올비율 NaN 0으로 채우기
df['알코올비율'] = df['알코올비율'].fillna(0)
df.head()
# Out:
#             국가   맥주  증류주   와인   알코올  대륙  주류소비량     알코올비율
# 0  Afghanistan    0    0    0   0.0  AS      0  0.000000
# 1      Albania   89  132   54   4.9  EU    275  0.017818
# 2      Algeria   25    0   14   0.7  AF     39  0.017949
# 3      Andorra  245  138  312  12.4  EU    695  0.017842
# 4       Angola  217   57   45   5.9  AF    319  0.018495

# %% [markdown]
# - Columns, Index 상호 변경
#
# - DataFrame.set_index(컬럼명) : 지정한 컬럼을 index로 지정함
# - DataFrame.set_index([컬럼명1, 컬럼명2, ...]) : 컬럼 목록을 index(Multi Index)로 지정함
# - columns에서 index 쪽으로 이동됨, 기존 index는 제거됨
# - DataFrame.reset_index() : 모든 index 가 columns로 이동됨
# - index는 RangeIndex로 대체됨

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.set_index('국가')[['맥주', '증류주', '와인']].sum(axis=1)
# Out:
# 국가
# Afghanistan                       0
# Albania                         275
# Algeria                          39
# Andorra                         695
# Angola                          319
# Antigua & Barbuda               275
# Argentina                       439
# Armenia                         211
# Australia                       545
# Austria                         545
# Azerbaijan                       72
# Bahamas                         349
# Bahrain                         112
# Bangladesh                        0
# Barbados                        352
# Belarus                         557
# Belgium                         591
# Belize                          385
# Benin                            51
# Bhutan                           23
# Bolivia                         216
# Bosnia-Herzegovina              257
# Botswana                        243
# Brazil                          406
# Brunei                           34
# Bulgaria                        577
# Burkina Faso                     39
# Burundi                          88
# Cote d'Ivoire                    45
# Cabo Verde                      216
# Cambodia                        123
# Cameroon                        152
# Canada                          462
# Central African Republic         20
# Chad                             17
# Chile                           426
# China                           279
# Colombia                        238
# Comoros                           5
# Congo                            86
# Cook Islands                    328
# Costa Rica                      247
# Croatia                         571
# Cuba                            235
# Cyprus                          459
# Czech Republic                  665
# North Korea                       0
# DR Congo                         36
# Denmark                         583
# Djibouti                         62
# Dominica                        364
# Dominican Republic              349
# Ecuador                         239
# Egypt                            11
# El Salvador                     123
# Equatorial Guinea               325
# Eritrea                          18
# Estonia                         477
# Ethiopia                         23
# Fiji                            113
# Finland                         493
# France                          648
# Gabon                           504
# Gambia                            9
# Georgia                         301
# Germany                         638
# Ghana                            44
# Greece                          463
# Grenada                         665
# Guatemala                       124
# Guinea                           11
# Guinea-Bissau                    80
# Guyana                          396
# Haiti                           328
# Honduras                        169
# Hungary                         634
# Iceland                         372
# India                           123
# Indonesia                         6
# Iran                              0
# Iraq                             12
# Ireland                         596
# Israel                          141
# Italy                           364
# Jamaica                         188
# Japan                           295
# Jordan                           28
# Kazakhstan                      382
# Kenya                            82
# Kiribati                         56
# Kuwait                            0
# Kyrgyzstan                      134
# Laos                            185
# Latvia                          559
# Lebanon                         106
# Lesotho                         111
# Liberia                         173
# Libya                             0
# Lithuania                       643
# Luxembourg                      640
# Madagascar                       45
# Malawi                           20
# Malaysia                         17
# Maldives                          0
# Mali                              7
# Malta                           369
# Marshall Islands                  0
# Mauritania                        0
# Mauritius                       147
# Mexico                          311
# Micronesia                      130
# Monaco                            0
# Mongolia                        274
# Montenegro                      273
# Morocco                          28
# Mozambique                       70
# Myanmar                           6
# Namibia                         380
# Nauru                            57
# Nepal                            11
# Netherlands                     529
# New Zealand                     457
# Nicaragua                       197
# Niger                             6
# Nigeria                          49
# Niue                            395
# Norway                          369
# Oman                             39
# Pakistan                          0
# Palau                           392
# Panama                          407
# Papua New Guinea                 84
# Paraguay                        404
# Peru                            344
# Philippines                     258
# Poland                          614
# Portugal                        600
# Qatar                            50
# South Korea                     165
# Moldova                         353
# Romania                         586
# Russian Federation              646
# Rwanda                           45
# St. Kitts & Nevis               431
# St. Lucia                       557
# St. Vincent & the Grenadines    352
# Samoa                           147
# San Marino                        0
# Sao Tome & Principe             234
# Saudi Arabia                      5
# Senegal                          17
# Serbia                          541
# Seychelles                      233
# Sierra Leone                     30
# Singapore                        83
# Slovakia                        605
# Slovenia                        597
# Solomon Islands                  68
# Somalia                           0
# South Africa                    382
# Spain                           553
# Sri Lanka                       120
# Sudan                            21
# Suriname                        313
# Swaziland                        94
# Sweden                          398
# Switzerland                     565
# Syria                            56
# Tajikistan                       17
# Thailand                        358
# Macedonia                       219
# Timor-Leste                       6
# Togo                             57
# Tonga                            62
# Trinidad & Tobago               360
# Tunisia                          74
# Turkey                           80
# Turkmenistan                    122
# Tuvalu                           56
# Uganda                           54
# Ukraine                         488
# United Arab Emirates            156
# United Kingdom                  540
# Tanzania                         43
# USA                             491
# Uruguay                         370
# Uzbekistan                      134
# Vanuatu                          50
# Venezuela                       436
# Vietnam                         114
# Yemen                             6
# Zambia                           55
# Zimbabwe                         86
# dtype: int64

# %%
#대륙, 국가를 index로 지정하고 대륙별, 국가명으로 정렬
df = df.set_index(['대륙','국가']).sort_index()
df
# Out:
#                                   맥주  증류주   와인   알코올  주류소비량     알코올비율
# 대륙 국가
# AF Algeria                        25    0   14   0.7     39  0.017949
#    Angola                        217   57   45   5.9    319  0.018495
#    Benin                          34    4   13   1.1     51  0.021569
#    Botswana                      173   35   35   5.4    243  0.022222
#    Burkina Faso                   25    7    7   4.3     39  0.110256
#    Burundi                        88    0    0   6.3     88  0.071591
#    Cabo Verde                    144   56   16   4.0    216  0.018519
#    Cameroon                      147    1    4   5.8    152  0.038158
#    Central African Republic       17    2    1   1.8     20  0.090000
#    Chad                           15    1    1   0.4     17  0.023529
#    Comoros                         1    3    1   0.1      5  0.020000
#    Congo                          76    1    9   1.7     86  0.019767
#    Cote d'Ivoire                  37    1    7   4.0     45  0.088889
#    DR Congo                       32    3    1   2.3     36  0.063889
#    Djibouti                       15   44    3   1.1     62  0.017742
#    Egypt                           6    4    1   0.2     11  0.018182
#    Equatorial Guinea              92    0  233   5.8    325  0.017846
#    Eritrea                        18    0    0   0.5     18  0.027778
#    Ethiopia                       20    3    0   0.7     23  0.030435
#    Gabon                         347   98   59   8.9    504  0.017659
#    Gambia                          8    0    1   2.4      9  0.266667
#    Ghana                          31    3   10   1.8     44  0.040909
#    Guinea                          9    0    2   0.2     11  0.018182
#    Guinea-Bissau                  28   31   21   2.5     80  0.031250
#    Kenya                          58   22    2   1.8     82  0.021951
#    Lesotho                        82   29    0   2.8    111  0.025225
#    Liberia                        19  152    2   3.1    173  0.017919
#    Libya                           0    0    0   0.0      0  0.000000
#    Madagascar                     26   15    4   0.8     45  0.017778
#    Malawi                          8   11    1   1.5     20  0.075000
#    Mali                            5    1    1   0.6      7  0.085714
#    Mauritania                      0    0    0   0.0      0  0.000000
#    Mauritius                      98   31   18   2.6    147  0.017687
#    Morocco                        12    6   10   0.5     28  0.017857
#    Mozambique                     47   18    5   1.3     70  0.018571
#    Namibia                       376    3    1   6.8    380  0.017895
#    Niger                           3    2    1   0.1      6  0.016667
#    Nigeria                        42    5    2   9.1     49  0.185714
#    Rwanda                         43    2    0   6.8     45  0.151111
#    Sao Tome & Principe            56   38  140   4.2    234  0.017949
#    Senegal                         9    1    7   0.3     17  0.017647
#    Seychelles                    157   25   51   4.1    233  0.017597
#    Sierra Leone                   25    3    2   6.7     30  0.223333
#    USA                           249  158   84   8.7    491  0.017719
# OC Australia                     261   72  212  10.4    545  0.019083
#    Cook Islands                    0  254   74   5.9    328  0.017988
#    Fiji                           77   35    1   2.0    113  0.017699
#    Kiribati                       21   34    1   1.0     56  0.017857
#    Marshall Islands                0    0    0   0.0      0  0.000000
#    Micronesia                     62   50   18   2.3    130  0.017692
#    Nauru                          49    0    8   1.0     57  0.017544
#    New Zealand                   203   79  175   9.3    457  0.020350
#    Niue                          188  200    7   7.0    395  0.017722
#    Palau                         306   63   23   6.9    392  0.017602
#    Papua New Guinea               44   39    1   1.5     84  0.017857
#    Samoa                         105   18   24   2.6    147  0.017687
#    Solomon Islands                56   11    1   1.2     68  0.017647
#    Tonga                          36   21    5   1.1     62  0.017742
#    Tuvalu                          6   41    9   1.0     56  0.017857
#    Vanuatu                        21   18   11   0.9     50  0.018000
# SA Argentina                     193   25  221   8.3    439  0.018907
#    Bolivia                       167   41    8   3.8    216  0.017593
#    Brazil                        245  145   16   7.2    406  0.017734
#    Chile                         130  124  172   7.6    426  0.017840
#    Colombia                      159   76    3   4.2    238  0.017647
#    Ecuador                       162   74    3   4.2    239  0.017573
#    Guyana                         93  302    1   7.1    396  0.017929
#    Paraguay                      213  117   74   7.3    404  0.018069
#    Peru                          163  160   21   6.1    344  0.017733
#    Suriname                      128  178    7   5.6    313  0.017891
#    Uruguay                       115   35  220   6.6    370  0.017838
#    Venezuela                     333  100    3   7.7    436  0.017661

# %%
df = df.reset_index()
df
# Out:
#      대륙                            국가   맥주  증류주   와인   알코올  주류소비량     알코올비율
# 0    AF                       Algeria   25    0   14   0.7     39  0.017949
# 1    AF                        Angola  217   57   45   5.9    319  0.018495
# 2    AF                         Benin   34    4   13   1.1     51  0.021569
# 3    AF                      Botswana  173   35   35   5.4    243  0.022222
# 4    AF                  Burkina Faso   25    7    7   4.3     39  0.110256
# 5    AF                       Burundi   88    0    0   6.3     88  0.071591
# 6    AF                    Cabo Verde  144   56   16   4.0    216  0.018519
# 7    AF                      Cameroon  147    1    4   5.8    152  0.038158
# 8    AF      Central African Republic   17    2    1   1.8     20  0.090000
# 9    AF                          Chad   15    1    1   0.4     17  0.023529
# 10   AF                       Comoros    1    3    1   0.1      5  0.020000
# 11   AF                         Congo   76    1    9   1.7     86  0.019767
# 12   AF                 Cote d'Ivoire   37    1    7   4.0     45  0.088889
# 13   AF                      DR Congo   32    3    1   2.3     36  0.063889
# 14   AF                      Djibouti   15   44    3   1.1     62  0.017742
# 15   AF                         Egypt    6    4    1   0.2     11  0.018182
# 16   AF             Equatorial Guinea   92    0  233   5.8    325  0.017846
# 17   AF                       Eritrea   18    0    0   0.5     18  0.027778
# 18   AF                      Ethiopia   20    3    0   0.7     23  0.030435
# 19   AF                         Gabon  347   98   59   8.9    504  0.017659
# 20   AF                        Gambia    8    0    1   2.4      9  0.266667
# 21   AF                         Ghana   31    3   10   1.8     44  0.040909
# 22   AF                        Guinea    9    0    2   0.2     11  0.018182
# 23   AF                 Guinea-Bissau   28   31   21   2.5     80  0.031250
# 24   AF                         Kenya   58   22    2   1.8     82  0.021951
# 25   AF                       Lesotho   82   29    0   2.8    111  0.025225
# 26   AF                       Liberia   19  152    2   3.1    173  0.017919
# 27   AF                         Libya    0    0    0   0.0      0  0.000000
# 28   AF                    Madagascar   26   15    4   0.8     45  0.017778
# 29   AF                        Malawi    8   11    1   1.5     20  0.075000
# 30   AF                          Mali    5    1    1   0.6      7  0.085714
# 31   AF                    Mauritania    0    0    0   0.0      0  0.000000
# 32   AF                     Mauritius   98   31   18   2.6    147  0.017687
# 33   AF                       Morocco   12    6   10   0.5     28  0.017857
# 34   AF                    Mozambique   47   18    5   1.3     70  0.018571
# 35   AF                       Namibia  376    3    1   6.8    380  0.017895
# 36   AF                         Niger    3    2    1   0.1      6  0.016667
# 37   AF                       Nigeria   42    5    2   9.1     49  0.185714
# 38   AF                        Rwanda   43    2    0   6.8     45  0.151111
# 39   AF           Sao Tome & Principe   56   38  140   4.2    234  0.017949
# 40   AF                       Senegal    9    1    7   0.3     17  0.017647
# 41   AF                    Seychelles  157   25   51   4.1    233  0.017597
# 42   AF                  Sierra Leone   25    3    2   6.7     30  0.223333
# 43   AF                       Somalia    0    0    0   0.0      0  0.000000
# 44   AF                  South Africa  225   76   81   8.2    382  0.021466
# 45   AF                         Sudan    8   13    0   1.7     21  0.080952
# 46   AF                     Swaziland   90    2    2   4.7     94  0.050000
# 47   AF                      Tanzania   36    6    1   5.7     43  0.132558
# 48   AF                          Togo   36    2   19   1.3     57  0.022807
# 49   AF                       Tunisia   51    3   20   1.3     74  0.017568
# 50   AF                        Uganda   45    9    0   8.3     54  0.153704
# 51   AF                        Zambia   32   19    4   2.5     55  0.045455
# 52   AF                      Zimbabwe   64   18    4   4.7     86  0.054651
# 53   AS                   Afghanistan    0    0    0   0.0      0  0.000000
# 54   AS                       Bahrain   42   63    7   2.0    112  0.017857
# 55   AS                    Bangladesh    0    0    0   0.0      0  0.000000
# 56   AS                        Bhutan   23    0    0   0.4     23  0.017391
# 57   AS                        Brunei   31    2    1   0.6     34  0.017647
# 58   AS                      Cambodia   57   65    1   2.2    123  0.017886
# 59   AS                         China   79  192    8   5.0    279  0.017921
# 60   AS                         India    9  114    0   2.2    123  0.017886
# 61   AS                     Indonesia    5    1    0   0.1      6  0.016667
# 62   AS                          Iran    0    0    0   0.0      0  0.000000
# 63   AS                          Iraq    9    3    0   0.2     12  0.016667
# 64   AS                        Israel   63   69    9   2.5    141  0.017730
# 65   AS                         Japan   77  202   16   7.0    295  0.023729
# 66   AS                        Jordan    6   21    1   0.5     28  0.017857
# 67   AS                    Kazakhstan  124  246   12   6.8    382  0.017801
# 68   AS                        Kuwait    0    0    0   0.0      0  0.000000
# 69   AS                    Kyrgyzstan   31   97    6   2.4    134  0.017910
# 70   AS                          Laos   62    0  123   6.2    185  0.033514
# 71   AS                       Lebanon   20   55   31   1.9    106  0.017925
# 72   AS                      Malaysia   13    4    0   0.3     17  0.017647
# 73   AS                      Maldives    0    0    0   0.0      0  0.000000
# 74   AS                      Mongolia   77  189    8   4.9    274  0.017883
# 177  OC               Solomon Islands   56   11    1   1.2     68  0.017647
# 178  OC                         Tonga   36   21    5   1.1     62  0.017742
# 179  OC                        Tuvalu    6   41    9   1.0     56  0.017857
# 180  OC                       Vanuatu   21   18   11   0.9     50  0.018000
# 181  SA                     Argentina  193   25  221   8.3    439  0.018907
# 182  SA                       Bolivia  167   41    8   3.8    216  0.017593
# 183  SA                        Brazil  245  145   16   7.2    406  0.017734
# 184  SA                         Chile  130  124  172   7.6    426  0.017840
# 185  SA                      Colombia  159   76    3   4.2    238  0.017647
# 186  SA                       Ecuador  162   74    3   4.2    239  0.017573
# 187  SA                        Guyana   93  302    1   7.1    396  0.017929
# 188  SA                      Paraguay  213  117   74   7.3    404  0.018069
# 189  SA                          Peru  163  160   21   6.1    344  0.017733
# 190  SA                      Suriname  128  178    7   5.6    313  0.017891
# 191  SA                       Uruguay  115   35  220   6.6    370  0.017838
# 192  SA                     Venezuela  333  100    3   7.7    436  0.017661

# %%
#전세계 평균 소비량과 South Korea의 소비량 비교
korea = df[df['국가'] == 'South Korea']
korea
# Out:
#     대륙           국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  AS  South Korea  140   16   9  9.8    165  0.059394

# %% [markdown]
# DataFrame에서 특정 행, 열 제거
# - DataFrame.drop(행, axis=0)
# - DataFrame.drop([행1, 행2, ...], axis=0)
# - DataFrame.drop(열, axis=1)
# - DataFrame.drop([열1, 열2, ...], axis=1)
# - indexing을 사용하여, 제거할 정보가 아닌 필요한 정보를 가져오기 하여 특정 행/열 제거

# %%
# South Korea 대륙정보 삭제
korea.drop('대륙',axis=1)
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %% [markdown]
# 원하는 컬럼만 추출하기
# - DataFrame.loc[:, 시작컬럼명:끝컬럼명]
# - DataFrame.iloc[:, 시작컬럼번호:끝컬럼번호+1]
#    - 특정 번호부터 끝까지 모든 컬럼을 대상으로 하며면 끝컬럼번호+1 정보를 생략함

# %%
korea.loc[:,'국가':'알코올비율']
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
df.loc[df['국가']=='South Korea','국가':'알코올비율']
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
korea.iloc[:,1:]
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
korea = korea.drop('대륙',axis=1)
korea
# Out:
#              국가   맥주  증류주  와인  알코올  주류소비량     알코올비율
# 85  South Korea  140   16   9  9.8    165  0.059394

# %%
worldwide = pd.DataFrame(df.mean())
worldwide
# Out:
# C:\Users\choic\AppData\Local\Temp\ipykernel_16736\198802507.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   worldwide = pd.DataFrame(df.mean())
#                 0
# 맥주     106.160622
# 증류주     80.994819
# 와인      49.450777
# 알코올      4.717098
# 주류소비량  236.606218
# 알코올비율    0.026115

# %%
wwT = worldwide.T
wwT
# Out:
#            맥주        증류주         와인       알코올       주류소비량     알코올비율
# 0  106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
wwT.insert(0,'국가','WorldWide')
wwT
# Out:
#           국가          맥주        증류주         와인       알코올       주류소비량     알코올비율
# 0  WorldWide  106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
compT = korea.append(wwT)
compT
# Out:
# C:\Users\choic\AppData\Local\Temp\ipykernel_16736\223240049.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   compT = korea.append(wwT)
#              국가          맥주        증류주         와인       알코올       주류소비량  \
# 85  South Korea  140.000000  16.000000   9.000000  9.800000  165.000000
# 0     WorldWide  106.160622  80.994819  49.450777  4.717098  236.606218
#
#        알코올비율
# 85  0.059394
# 0   0.026115

# %% [markdown]
# 여러 개의 DataFrame을 합쳐 하나의 DataFrame 생성
# - pd.concat([df1, df2, ....], axis=0) : index 방향으로 합치기
# - pd.concat([df1, df2, ....], axis=1) : columns 방향으로 합치기
# - DataFrame.append()와는 달리 여러 개의 DataFrame 목록을 주어 여러 개를 한 번에 합칠 수 있음

# %%
df2 = pd.concat([korea, wwT])
df2
# Out:
#              국가          맥주        증류주         와인       알코올       주류소비량  \
# 85  South Korea  140.000000  16.000000   9.000000  9.800000  165.000000
# 0     WorldWide  106.160622  80.994819  49.450777  4.717098  236.606218
#
#        알코올비율
# 85  0.059394
# 0   0.026115

# %%
df3 = df2.set_index('국가')
df3
# Out:
#                      맥주        증류주         와인       알코올       주류소비량     알코올비율
# 국가
# South Korea  140.000000  16.000000   9.000000  9.800000  165.000000  0.059394
# WorldWide    106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
df3 = df2.set_index('국가')
df3
# Out:
#                      맥주        증류주         와인       알코올       주류소비량     알코올비율
# 국가
# South Korea  140.000000  16.000000   9.000000  9.800000  165.000000  0.059394
# WorldWide    106.160622  80.994819  49.450777  4.717098  236.606218  0.026115

# %%
df3.T
# Out:
# 국가     South Korea   WorldWide
# 맥주      140.000000  106.160622
# 증류주      16.000000   80.994819
# 와인        9.000000   49.450777
# 알코올       9.800000    4.717098
# 주류소비량   165.000000  236.606218
# 알코올비율     0.059394    0.026115

# %%
# 주류소비량이 있으면서 맥주를 소비하지 않는 나라의 맥주/증류주/와인/알코올/대륙 등의 정보 구하기
df.loc[(df['주류소비량'] > 0) & (df['맥주'] <= 0),'대륙':'알코올']
# Out:
#      대륙            국가  맥주  증류주  와인  알코올
# 83   AS  Saudi Arabia   0    5   0  0.1
# 166  OC  Cook Islands   0  254  74  5.9

# %%
#주류소비량은 있으면서 맥주를 소비하지 않는 국가의 국가명
#사우디는 정보를 공개하지 않았겠지?
df.loc[(df['주류소비량'] > 0) & (df['맥주'] <= 0),'국가'].to_list()
# Out:
# ['Saudi Arabia', 'Cook Islands']

# %%
#주류소비량 정보가 없는 국가는?
#이슬람 국가 대부분,북한 0, 정보를 공개하지 않은거겠지?
df[df['주류소비량'] == 0]
# Out:
#      대륙                국가  맥주  증류주  와인  알코올  주류소비량  알코올비율
# 27   AF             Libya   0    0   0  0.0      0    0.0
# 31   AF        Mauritania   0    0   0  0.0      0    0.0
# 43   AF           Somalia   0    0   0  0.0      0    0.0
# 53   AS       Afghanistan   0    0   0  0.0      0    0.0
# 55   AS        Bangladesh   0    0   0  0.0      0    0.0
# 62   AS              Iran   0    0   0  0.0      0    0.0
# 68   AS            Kuwait   0    0   0  0.0      0    0.0
# 73   AS          Maldives   0    0   0  0.0      0    0.0
# 77   AS       North Korea   0    0   0  0.0      0    0.0
# 79   AS          Pakistan   0    0   0  0.0      0    0.0
# 126  EU            Monaco   0    0   0  0.0      0    0.0
# 133  EU        San Marino   0    0   0  0.0      0    0.0
# 169  OC  Marshall Islands   0    0   0  0.0      0    0.0

# %%
df.loc[df['주류소비량']==0,'국가'].to_list()
# Out:
# ['Libya',
#  'Mauritania',
#  'Somalia',
#  'Afghanistan',
#  'Bangladesh',
#  'Iran',
#  'Kuwait',
#  'Maldives',
#  'North Korea',
#  'Pakistan',
#  'Monaco',
#  'San Marino',
#  'Marshall Islands']

# %%
# 맥주 소비량 TOP5 국가
df.sort_values('맥주',ascending = False).head(5)
# Out:
#      대륙              국가   맥주  증류주   와인   알코올  주류소비량     알코올비율
# 35   AF         Namibia  376    3    1   6.8    380  0.017895
# 108  EU  Czech Republic  361  170  134  11.8    665  0.017744
# 19   AF           Gabon  347   98   59   8.9    504  0.017659
# 114  EU         Germany  346  117  175  11.3    638  0.017712
# 121  EU       Lithuania  343  244   56  12.9    643  0.020062

# %%
# 전세계 맥주소비량 평균보다 큰 국가 수는?
df.loc[df['맥주']>df['맥주'].mean(),'국가'].count()
# Out:
# 76

# %%
# 전세계 맥주소비량 평균보다 큰 국가는?
df.loc[df['맥주']>df['맥주'].mean(),'국가'].to_list()
# Out:
# ['Angola',
#  'Botswana',
#  'Cabo Verde',
#  'Cameroon',
#  'Gabon',
#  'Namibia',
#  'Seychelles',
#  'South Africa',
#  'Kazakhstan',
#  'Russian Federation',
#  'South Korea',
#  'Vietnam',
#  'Andorra',
#  'Austria',
#  'Belarus',
#  'Belgium',
#  'Bulgaria',
#  'Croatia',
#  'Cyprus',
#  'Czech Republic',
#  'Denmark',
#  'Estonia',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Hungary',
#  'Iceland',
#  'Ireland',
#  'Latvia',
#  'Lithuania',
#  'Luxembourg',
#  'Malta',
#  'Moldova',
#  'Netherlands',
#  'Norway',
#  'Poland',
#  'Portugal',
#  'Romania',
#  'Serbia',
#  'Slovakia',
#  'Slovenia',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'Ukraine',
#  'United Kingdom',
#  'Bahamas',
#  'Barbados',
#  'Belize',
#  'Canada',
#  'Costa Rica',
#  'Dominican Republic',
#  'Grenada',
#  'Mexico',
#  'Panama',
#  'St. Kitts & Nevis',
#  'St. Lucia',
#  'St. Vincent & the Grenadines',
#  'Trinidad & Tobago',
#  'USA',
#  'Australia',
#  'New Zealand',
#  'Niue',
#  'Palau',
#  'Argentina',
#  'Bolivia',
#  'Brazil',
#  'Chile',
#  'Colombia',
#  'Ecuador',
#  'Paraguay',
#  'Peru',
#  'Suriname',
#  'Uruguay',
#  'Venezuela']

# %%
# 전세계 맥주소비량 평균
df['맥주'].mean()
# Out:
# 106.16062176165804

# %%
#대륙 별 맥주소비량 평균
df.groupby('대륙').mean()
# Out:
#             맥주         증류주          와인       알코올       주류소비량     알코올비율
# 대륙
# AF   61.471698   16.339623   16.264151  3.007547   94.075472  0.049741
# AS   37.045455   60.840909    9.068182  2.170455  106.954545  0.016359
# EU  193.777778  132.555556  142.222222  8.617778  468.555556  0.017527
# NA  145.434783  165.739130   24.521739  5.995652  335.695652  0.017854
# OC   89.687500   58.437500   35.625000  3.381250  183.750000  0.016895
# SA  175.083333  114.750000   62.416667  6.308333  352.250000  0.017868

# %%
# 대륙별 주류 소비량 중앙값
df.groupby('대륙').median()
# Out:
#        맥주    증류주     와인    알코올  주류소비량     알코올비율
# 대륙
# AF   32.0    3.0    2.0   2.30   49.0  0.021951
# AS   17.5   16.0    1.0   1.20   68.0  0.017843
# EU  219.0  122.0  128.0  10.00  541.0  0.017865
# NA  143.0  137.0   11.0   6.30  349.0  0.017818
# OC   52.5   37.0    8.5   1.75   98.5  0.017732
# SA  162.5  108.5   12.0   6.85  383.0  0.017786

# %%
#대륙별 맥주 소비량 평균
df.groupby('대륙')[['맥주']].mean()
# Out:
#             맥주
# 대륙
# AF   61.471698
# AS   37.045455
# EU  193.777778
# NA  145.434783
# OC   89.687500
# SA  175.083333

# %%
# 전세계 맥주 소비량 평균보다 많은 맥주를 소비하는 대륙은?
temp = df.groupby('대륙')[['맥주']].mean()
temp[temp['맥주']>df['맥주'].mean()]
# Out:
#             맥주
# 대륙
# EU  193.777778
# NA  145.434783
# SA  175.083333

# %%
df.groupby('대륙')[['맥주','와인']].agg(['mean','median','max'])
# Out:
#             맥주                      와인
#           mean median  max        mean median  max
# 대륙
# AF   61.471698   32.0  376   16.264151    2.0  233
# AS   37.045455   17.5  247    9.068182    1.0  123
# EU  193.777778  219.0  361  142.222222  128.0  370
# NA  145.434783  143.0  285   24.521739   11.0  100
# OC   89.687500   52.5  306   35.625000    8.5  212
# SA  175.083333  162.5  333   62.416667   12.0  221

# %%
#pivot_table 사용
df.pivot_table(index='대륙',values = ['맥주','와인'],aggfunc=['mean','median','max'])
# Out:
#           mean             median         max
#             맥주          와인     맥주     와인   맥주   와인
# 대륙
# AF   61.471698   16.264151   32.0    2.0  376  233
# AS   37.045455    9.068182   17.5    1.0  247  123
# EU  193.777778  142.222222  219.0  128.0  361  370
# NA  145.434783   24.521739  143.0   11.0  285  100
# OC   89.687500   35.625000   52.5    8.5  306  212
# SA  175.083333   62.416667  162.5   12.0  333  221

# %%
df.pivot_table(columns='대륙',values=['맥주','와인'],aggfunc=['mean','median'])
# Out:
#          mean                                              ... median         \
# 대륙         AF         AS          EU          NA       OC  ...     AS     EU
# 맥주  61.471698  37.045455  193.777778  145.434783  89.6875  ...   17.5  219.0
# 와인  16.264151   9.068182  142.222222   24.521739  35.6250  ...    1.0  128.0
#
#
# 대륙     NA    OC     SA
# 맥주  143.0  52.5  162.5
# 와인   11.0   8.5   12.0
#
# [2 rows x 12 columns]

# %%
#대륙 별 맥주와 와인 통계값
df.groupby('대륙')[['맥주','와인']].agg(['mean','median','max'])
# Out:
#             맥주                      와인
#           mean median  max        mean median  max
# 대륙
# AF   61.471698   32.0  376   16.264151    2.0  233
# AS   37.045455   17.5  247    9.068182    1.0  123
# EU  193.777778  219.0  361  142.222222  128.0  370
# NA  145.434783  143.0  285   24.521739   11.0  100
# OC   89.687500   52.5  306   35.625000    8.5  212
# SA  175.083333  162.5  333   62.416667   12.0  221
